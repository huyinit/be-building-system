# %%
from pymongo import MongoClient
from pymongo.server_api import ServerApi
from faker import Faker
import random
import json

# Khởi tạo Faker để tạo dữ liệu giả
fake = Faker('vi_VN')  # Thiết lập locale để tạo dữ liệu tiếng Việt

# Thay thế URI của bạn
uri = "mongodb+srv://huyreeve:h123456@cluster0.bd57hcu.mongodb.net/building?retryWrites=true&w=majority&appName=Cluster0"

# Tạo client mới và kết nối đến server
client = MongoClient(uri, server_api=ServerApi('1'))

# %%
# Gửi lệnh ping để xác nhận kết nối thành công
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
    
    # Chọn cơ sở dữ liệu và collection
    db = client['building']  # Thay bằng tên cơ sở dữ liệu của bạn
    cong_ty_collection = db['NhanVienToaNha']
    
    # Xóa tất cả dữ liệu trong collection
    result = cong_ty_collection.delete_many({})
    print(f"Deleted {result.deleted_count} documents from collection 'NhanVienToaNha'.")
    
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# Deleted 100 documents from collection 'NhanVienToaNha'.

# %%
# Gửi lệnh ping để xác nhận kết nối thành công
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
    
    # Chọn cơ sở dữ liệu và collection
    db = client['building']  # Thay bằng tên cơ sở dữ liệu của bạn
    
    # Lấy collection CongTy
    cong_ty_collection = db['CongTy']
    # Lấy tất cả dữ liệu từ collection CongTy
    companies = list(cong_ty_collection.find())
    company_ids = [str(company['_id']) for company in companies]  # Chuyển ObjectId thành string
    
    # Lấy collection NhanVienCongTy
    nhan_vien_collection = db['NhanVienToaNha']
    
    # Số lượng dữ liệu cần tạo
    num_records = 50
    
    # Tạo dữ liệu ngẫu nhiên cho NhanVienCongTy
    nhan_vien_data = []
    for _ in range(num_records):
        nhan_vien = {
            'maNhanVien': fake.uuid4().replace('-', ''),  # UUID không có dấu gạch ngang
            'ten': fake.name(),  # Tên ngẫu nhiên
            'ngaySinh': fake.date_of_birth(minimum_age=18, maximum_age=65).strftime('%Y-%m-%d'),  # Ngày sinh ngẫu nhiên
            'diaChi': fake.address(),  # Địa chỉ ngẫu nhiên
            'soDienThoai': fake.phone_number(),  # Số điện thoại ngẫu nhiên
            'bac': random.choice(['Junior', 'Mid', 'Senior']),  # Chọn bậc công việc ngẫu nhiên
            'viTri': fake.job(),  # Vị trí công việc ngẫu nhiên
        }
        print(nhan_vien)
        nhan_vien_data.append(nhan_vien)
    
    # Lưu dữ liệu vào collection
    nhan_vien_collection.insert_many(nhan_vien_data)
    
    print("Dữ liệu ngẫu nhiên cho NhanVienCongTy đã được tạo thành công.")
    
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# {'maNhanVien': '623d9f06540644c7bdfd4bddb39653f7', 'ten': 'Anh Tấn Hoàng', 'ngaySinh': '2003-10-17', 'diaChi': '65 Đặng Đường\nQuận JaneQuận, 556442', 'soDienThoai': '(07)915-2086', 'bac': 'Mid', 'viTri': 'Luật sư'}
# {'maNhanVien': 'a6ecbe48daf7498f91153f7561806a23', 'ten': 'Vũ Phú Phạm', 'ngaySinh': '1993-03-01', 'diaChi': '11 Mai Khu\nThị xã JanePhường, 139249', 'soDienThoai': '+84-37-941 0998', 'bac': 'Mid', 'viTri': 'Project Manager'}
# {'maNhanVien': 'dd8944633d9c41cab9458e4ca16bfbbc', 'ten': 'Quý cô Mai Dương', 'ngaySinh': '1958-11-10', 'diaChi': '724 Phạm Làng\nHuyện JaneQuận, 736921', 'soDienThoai': '+84-11-962 4039', 'bac': 'Senior', 'viTri': 'Luật sư'}
# {'maNhanVien': '8fe2dddd7fd64d20ae72612dfb2c324f', 'ten': 'Chị Linh Bùi', 'ngaySinh': '1989-08-07', 'diaChi': '8 Phạm Làng\nThị xã JaneHuyện, 507579', 'soDienThoai': '+84-50-823 2259', 'bac': 'Senior', 'viTri': 'Marketing Manager'}
# ...

# %%
import json
# Gửi lệnh ping để xác nhận kết nối thành công
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
    
    # Chọn cơ sở dữ liệu và collection
    db = client['building']  # Thay bằng tên cơ sở dữ liệu của bạn
    NhanVienCongTy_collection = db['NhanVienToaNha']
    
    # Lấy tất cả dữ liệu từ collection
    NhanVienCongTys = list(NhanVienCongTy_collection.find())
    
    # Chuyển đổi ObjectId sang string để lưu vào JSON
    for NhanVienCongTy in NhanVienCongTys:
        print(NhanVienCongTy)
        NhanVienCongTy['_id'] = str(NhanVienCongTy['_id'])
    
    # Lưu dữ liệu vào file JSON
    with open('nhavientoanha.json', 'w') as file:
        json.dump(NhanVienCongTys, file, indent=4, ensure_ascii=False)
    
    print("Data has been saved to nhavientoanha.json")
    
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# {'_id': ObjectId('66ff6e63e3eaaa7efe9f7167'), 'maNhanVien': '623d9f06540644c7bdfd4bddb39653f7', 'ten': 'Anh Tấn Hoàng', 'ngaySinh': '2003-10-17', 'diaChi': '65 Đặng Đường\nQuận JaneQuận, 556442', 'soDienThoai': '(07)915-2086', 'bac': 'Mid', 'viTri': 'Luật sư'}
# {'_id': ObjectId('66ff6e63e3eaaa7efe9f7168'), 'maNhanVien': 'a6ecbe48daf7498f91153f7561806a23', 'ten': 'Vũ Phú Phạm', 'ngaySinh': '1993-03-01', 'diaChi': '11 Mai Khu\nThị xã JanePhường, 139249', 'soDienThoai': '+84-37-941 0998', 'bac': 'Mid', 'viTri': 'Project Manager'}
# {'_id': ObjectId('66ff6e63e3eaaa7efe9f7169'), 'maNhanVien': 'dd8944633d9c41cab9458e4ca16bfbbc', 'ten': 'Quý cô Mai Dương', 'ngaySinh': '1958-11-10', 'diaChi': '724 Phạm Làng\nHuyện JaneQuận, 736921', 'soDienThoai': '+84-11-962 4039', 'bac': 'Senior', 'viTri': 'Luật sư'}
# ...
