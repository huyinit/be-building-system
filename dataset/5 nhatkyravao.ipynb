# %%
from pymongo import MongoClient
from pymongo.server_api import ServerApi
from faker import Faker
import random
import json
from datetime import datetime

# Khởi tạo Faker để tạo dữ liệu giả
fake = Faker('vi_VN')  # Thiết lập locale để tạo dữ liệu tiếng Việt

# Thay thế URI của bạn
uri = "mongodb+srv://huyreeve:h123456@cluster0.bd57hcu.mongodb.net/building?retryWrites=true&w=majority&appName=Cluster0"

# Tạo client mới và kết nối đến server
client = MongoClient(uri, server_api=ServerApi('1'))


client.admin.command('ping')
print("Pinged your deployment. You successfully connected to MongoDB!")

# Chọn cơ sở dữ liệu và collection
db = client['building']  # Thay bằng tên cơ sở dữ liệu của bạn

# Lấy collection NhanVienCongTy
nhan_vien_collection = db['NhanVienCongTy']
# Lấy tất cả dữ liệu từ collection NhanVienCongTy
employees = list(nhan_vien_collection.find())
employee_ids = [str(employee['_id']) for employee in employees]  # Chuyển ObjectId thành string

# Lấy collection NhatKyRaVao
nhat_ky_ra_vao_collection = db['NhatKyRaVao']

# Tạo dữ liệu giả cho NhatKyRaVao
nhat_ky_ra_vao_data = []
num_entries = 4000  # Số lượng dữ liệu cần tạo
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# Gửi lệnh ping để xác nhận kết nối thành công
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
    
    # Chọn cơ sở dữ liệu và collection
    db = client['building']  # Thay bằng tên cơ sở dữ liệu của bạn
    cong_ty_collection = db['NhatKyRaVao']
    
    # Xóa tất cả dữ liệu trong collection
    result = cong_ty_collection.delete_many({})
    print(f"Deleted {result.deleted_count} documents from collection 'NhatKyRaVao'.")
    
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# Deleted 4500 documents from collection 'NhatKyRaVao'.

# %%
from datetime import datetime, timedelta

nhat_ky_ra_vao_data = []
num_entries = 4000  # Số lượng dữ liệu cần tạo

# Danh sách các vị trí cụ thể
vi_tri_options = ['Tầng 1', 'Tầng 2', 'Hầm B1', 'Hầm B2']

# Thiết lập khoảng thời gian để tạo thời gian ngẫu nhiên
start_date = datetime(2023, 4, 1)  # Ngày bắt đầu
end_date = datetime(2024, 9, 30)  # Ngày kết thúc

def get_random_date(start, end):
    delta = end - start
    random_days = random.randint(0, delta.days)
    random_seconds = random.randint(0, 86400)  # Số giây trong một ngày
    return start + timedelta(days=random_days, seconds=random_seconds)

for i in range (len (employee_ids)):
    for _ in range(3):
        # nhan_vien_id = random.choice(employee_ids)
        nhan_vien_id = employees[i]['_id']
        thoi_gian = get_random_date(start_date, end_date)  # Tạo thời gian ngẫu nhiên
        vi_tri = random.choice(vi_tri_options)  # Chọn ngẫu nhiên từ danh sách các vị trí
        
        nhat_ky_ra_vao_entry = {
            'nhanVienId': nhan_vien_id,
            'thoiGian': thoi_gian,  # Thời gian đã được tạo là đối tượng datetime
            'viTri': vi_tri
        }
        
        nhat_ky_ra_vao_data.append(nhat_ky_ra_vao_entry)
        print(nhat_ky_ra_vao_entry)
print(len(nhat_ky_ra_vao_data))
# Thêm dữ liệu vào collection NhatKyRaVao
nhat_ky_ra_vao_collection.insert_many(nhat_ky_ra_vao_data)
# Out:
# {'nhanVienId': ObjectId('66ff61c2af217422fb3b533f'), 'thoiGian': datetime.datetime(2024, 7, 17, 2, 34, 44), 'viTri': 'Tầng 2'}
# {'nhanVienId': ObjectId('66ff61c2af217422fb3b533f'), 'thoiGian': datetime.datetime(2023, 8, 26, 17, 44, 3), 'viTri': 'Tầng 2'}
# {'nhanVienId': ObjectId('66ff61c2af217422fb3b533f'), 'thoiGian': datetime.datetime(2023, 9, 4, 5, 46, 27), 'viTri': 'Tầng 2'}
# {'nhanVienId': ObjectId('66ff61c2af217422fb3b5340'), 'thoiGian': datetime.datetime(2024, 6, 6, 21, 54), 'viTri': 'Hầm B1'}
# {'nhanVienId': ObjectId('66ff61c2af217422fb3b5340'), 'thoiGian': datetime.datetime(2023, 6, 19, 4, 36, 20), 'viTri': 'Tầng 2'}
# {'nhanVienId': ObjectId('66ff61c2af217422fb3b5340'), 'thoiGian': datetime.datetime(2023, 7, 20, 18, 31, 1), 'viTri': 'Tầng 2'}
# {'nhanVienId': ObjectId('66ff61c2af217422fb3b5341'), 'thoiGian': datetime.datetime(2024, 8, 15, 19, 51, 52), 'viTri': 'Hầm B1'}
# ...

# %%
import json
# Gửi lệnh ping để xác nhận kết nối thành công
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
    
    # Chọn cơ sở dữ liệu và collection
    db = client['building']  # Thay bằng tên cơ sở dữ liệu của bạn
    NhanVienCongTy_collection = db['NhatKyRaVao']
    
    # Lấy tất cả dữ liệu từ collection
    NhanVienCongTys = list(NhanVienCongTy_collection.find())
    
    # Chuyển đổi ObjectId sang string để lưu vào JSON
    for NhanVienCongTy in NhanVienCongTys:
        print(NhanVienCongTy)
        NhanVienCongTy['_id'] = str(NhanVienCongTy['_id'])
        NhanVienCongTy['nhanVienId'] = str(NhanVienCongTy['nhanVienId'])
        NhanVienCongTy['thoiGian'] = str(NhanVienCongTy['thoiGian'])
    
    # Lưu dữ liệu vào file JSON
    with open('NhatKyRaVao.json', 'w') as file:
        json.dump(NhanVienCongTys, file, indent=4, ensure_ascii=False)
    
    print("Data has been saved to NhatKyRaVao.json")
    
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# {'_id': ObjectId('66ffa58a9262b6c3587cb3df'), 'nhanVienId': ObjectId('66ff61c2af217422fb3b533f'), 'thoiGian': datetime.datetime(2024, 7, 17, 2, 34, 44), 'viTri': 'Tầng 2'}
# {'_id': ObjectId('66ffa58a9262b6c3587cb3e0'), 'nhanVienId': ObjectId('66ff61c2af217422fb3b533f'), 'thoiGian': datetime.datetime(2023, 8, 26, 17, 44, 3), 'viTri': 'Tầng 2'}
# {'_id': ObjectId('66ffa58a9262b6c3587cb3e1'), 'nhanVienId': ObjectId('66ff61c2af217422fb3b533f'), 'thoiGian': datetime.datetime(2023, 9, 4, 5, 46, 27), 'viTri': 'Tầng 2'}
# {'_id': ObjectId('66ffa58a9262b6c3587cb3e2'), 'nhanVienId': ObjectId('66ff61c2af217422fb3b5340'), 'thoiGian': datetime.datetime(2024, 6, 6, 21, 54), 'viTri': 'Hầm B1'}
# {'_id': ObjectId('66ffa58a9262b6c3587cb3e3'), 'nhanVienId': ObjectId('66ff61c2af217422fb3b5340'), 'thoiGian': datetime.datetime(2023, 6, 19, 4, 36, 20), 'viTri': 'Tầng 2'}
# ...
